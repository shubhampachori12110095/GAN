# %%
#%matplotlib inline
import os 
import argparse
import random

random.seed()
os.environ["THEANO_FLAGS"]  = "mode=FAST_RUN,device=gpu1,floatX=float32,lib.cnmem=1"
parser = argparse.ArgumentParser(description='Train model')                                                 
parser.add_argument('--backend', type=str, default="theano", help="theano or tensorflow")                      
parser.add_argument('--generator', type=str, default="upsampling", help="upsampling or deconv or subpixel")    
parser.add_argument('--discriminator', type=str, default="discriminator", help="discriminator discriminator_resnet")
parser.add_argument('--dset', type=str, default="mnist", help="mnistM or washington_vandal50k or washington_vandal12classes")             
parser.add_argument('--img_dim', default=64, type=int, help="Image width == height")                           
parser.add_argument('--nb_epoch', default=10000, type=int, help="Number of epochs")                              
parser.add_argument('--batch_size', default=32, type=int, help='Batch size for training purpose; for testing is hardcoded at 32')                                   
parser.add_argument('--n_batch_per_epoch', default=100, type=int, help="Number of batch per epochs")           
parser.add_argument('--bn_mode', default=2, type=int, help="Batch norm mode")                                  
parser.add_argument('--noise_dim', default=100, type=int, help="noise sampler dimension")                      
parser.add_argument('--noise_scale', default=0.5, type=float, help="noise sampler variance")                   
parser.add_argument('--disc_iterations', default=5, type=int, help="Number of discriminator iterations")
parser.add_argument('--clamp_lower', default=-100, type=float, help="Clamp weights below this value")         
parser.add_argument('--clamp_upper', default=100, type=float, help="Clamp weights above this value")          
parser.add_argument('--opt_D', type=str, default="RMSprop", help="Optimizer for the discriminator")            
parser.add_argument('--opt_G', type=str, default="RMSprop", help="Optimizer for the generator")                
parser.add_argument('--lr_D', type=float, default=5E-5, help="learning rate for the discriminator")            
parser.add_argument('--lr_G', type=float, default=5E-5, help="learning rate for the generator")                
parser.add_argument('--use_mbd', action="store_true", help="use mini batch disc")
parser.add_argument('--deterministic', action="store_true", help="remove the noise input")
parser.add_argument('--inject_noise', action="store_true", help="inject noise into each layer")
parser.add_argument('--model', type=str, default="lsgan", help="wgan or lsgan") 
parser.add_argument('--no_supertrain', action="store_true", help="no discriminator supertraining") 
parser.add_argument('--monsterClass', action="store_true", help="Discriminator with 2x classes")
parser.add_argument('--resume', action="store_true", help="load GAN weights from previous train")#lsgan_VandWash1 is the name for the run Vand Wash no deterministic, no monsterclass
parser.add_argument('--name', type=str, default="monsterClass_deterministic", help="name of the run, used for saving and loading weights")
parser.add_argument('--wd', type=float, default=0.0, help="weight decay for generator/discriminator")

###simulating the main.py calling with corresponding parameters:
args = parser.parse_args(' --dset Vand_Vand_12class_LMDB --monsterClass --deterministic --disc_iterations 15 --no_supertrain --wd 1E-5 --opt_D Adam --opt_G Adam --lr_D 1E-3 --lr_G 1E-3'.split())
######
print args
assert args.dset in ["mnistM","washington_vandal50k","washington_vandal12classes","washington_vandal12classesNoBackground","Wash_Vand_12class_LMDB","Vand_Vand_12class_LMDB"]                                                      
assert args.opt_G in ["RMSprop", "SGD", "Adam", "AdamWithWeightnorm"], "Unsupported optimizer"                 
assert args.opt_D in ["RMSprop", "SGD", "Adam", "AdamWithWeightnorm"], "Unsupported optimizer" 

# Set the backend by modifying the env variable                                                                
if args.backend == "theano":                                                                                   
    os.environ["KERAS_BACKEND"] = "theano"                                                                     
elif args.backend == "tensorflow":                                                                             
    os.environ["KERAS_BACKEND"] = "tensorflow"  
import keras.backend as K
# manually set dim ordering otherwise it is not changed                                                        
if args.backend == "theano":                                                                                   
    image_dim_ordering = "th"                                                                                  
    K.set_image_dim_ordering(image_dim_ordering)                                                               
elif args.backend == "tensorflow":                                                                             
    image_dim_ordering = "tf"                                                                                  
    K.set_image_dim_ordering(image_dim_ordering)
import train_WGAN
# Set default params
d_params = {"generator": args.generator,
            "discriminator": args.discriminator,
            "dset": args.dset,
            "img_dim": args.img_dim,
            "nb_epoch": args.nb_epoch,
            "batch_size": args.batch_size,
            "n_batch_per_epoch": args.n_batch_per_epoch,
            "bn_mode": args.bn_mode,
            "noise_dim": args.noise_dim,
            "noise_scale": args.noise_scale,
            "disc_iterations": args.disc_iterations,
            "clamp_lower": args.clamp_lower,
            "clamp_upper": args.clamp_upper,
            "lr_D": args.lr_D,
            "lr_G": args.lr_G,
            "opt_D": args.opt_D,
            "opt_G": args.opt_G,
            "use_mbd": args.use_mbd,
            "deterministic": args.deterministic,
            "image_dim_ordering": image_dim_ordering,
            "model": args.model,
            "no_supertrain": args.no_supertrain,
            "monsterClass": args.monsterClass,
            "resume": args.resume,
            "name": args.name,
            "inject_noise": args.inject_noise,
            "wd" : args.wd
            }

# Launch training
train_WGAN.train(**d_params)
# Out:
# Namespace(backend='theano', batch_size=32, bn_mode=2, clamp_lower=-100, clamp_upper=100, deterministic=True, disc_iterations=15, discriminator='discriminator', dset='Vand_Vand_12class_LMDB', generator='upsampling', img_dim=64, inject_noise=False, lr_D=0.001, lr_G=0.001, model='lsgan', monsterClass=True, n_batch_per_epoch=100, name='monsterClass_deterministic', nb_epoch=10000, no_supertrain=True, noise_dim=100, noise_scale=0.5, opt_D='Adam', opt_G='Adam', resume=False, use_mbd=False, wd=1e-05)
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 1: GeForce GTX TITAN X (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5110)
# Experiment parameters:
# noise_dim 100
# image_dim_ordering th
# opt_D Adam
# use_mbd False
# discriminator discriminator
# clamp_lower -100
# generator upsampling
# nb_epoch 10000
# deterministic True
# n_batch_per_epoch 100
# disc_iterations 15
# no_supertrain True
# monsterClass True
# clamp_upper 100
# opt_G Adam
# wd 1e-05
# resume False
# batch_size 32
# dset Vand_Vand_12class_LMDB
# name monsterClass_deterministic
# noise_scale 0.5
# bn_mode 2
# lr_G 0.001
# img_dim 64
# lr_D 0.001
# inject_noise False
# model lsgan
#
#
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# generator_image_input (InputLaye (None, 1, 64, 64)     0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 64, 64, 64)    640         generator_image_input[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 64, 64, 64)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 64, 64, 64)    36928       activation_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNorma (None, 64, 64, 64)    256         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 64, 64)    0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 64, 64, 64)    36928       activation_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 64, 64, 64)    256         convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 64, 64, 64)    0           batchnormalization_3[0][0]
#                                                                    activation_2[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 64, 64, 64)    0           merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 64, 64, 64)    36928       activation_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 64, 64, 64)    256         convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 64, 64, 64)    0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 64, 64, 64)    36928       activation_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNorma (None, 64, 64, 64)    256         convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 64, 64, 64)    0           activation_4[0][0]
#                                                                    batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 64, 64, 64)    0           merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 64, 64, 64)    36928       activation_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNorma (None, 64, 64, 64)    256         convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 64, 64, 64)    0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 64, 64, 64)    36928       activation_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNorma (None, 64, 64, 64)    256         convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 64, 64, 64)    0           activation_6[0][0]
#                                                                    batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 64, 64, 64)    0           merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 64, 64, 64)    36928       activation_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNorma (None, 64, 64, 64)    256         convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 64, 64, 64)    0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 64, 64, 64)    36928       activation_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNorma (None, 64, 64, 64)    256         convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 64, 64, 64)    0           activation_8[0][0]
#                                                                    batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 64, 64, 64)    0           merge_4[0][0]
# ____________________________________________________________________________________________________
# gen_conv2d_final (Convolution2D) (None, 1, 64, 64)     65          activation_10[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 1, 64, 64)     0           gen_conv2d_final[0][0]
# ====================================================================================================
# Total params: 298,177
# Trainable params: 297,153
# Non-trainable params: 1,024
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# discriminator_input (InputLayer) (None, 1, 64, 64)     0
# ____________________________________________________________________________________________________
# disc_conv2d_1 (Convolution2D)    (None, 64, 32, 32)    576         discriminator_input[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorm (None, 64, 32, 32)    256         disc_conv2d_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)          (None, 64, 32, 32)    0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# disc_conv2d_2 (Convolution2D)    (None, 128, 16, 16)   73728       leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorm (None, 128, 16, 16)   512         disc_conv2d_2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)          (None, 128, 16, 16)   0           batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# disc_conv2d_3 (Convolution2D)    (None, 256, 8, 8)     294912      leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 256, 8, 8)     1024        disc_conv2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)          (None, 256, 8, 8)     0           batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# disc_conv2d_4 (Convolution2D)    (None, 512, 4, 4)     1179648     leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 512, 4, 4)     2048        disc_conv2d_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)          (None, 512, 4, 4)     0           batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# globalaveragepooling2d_1 (Global (None, 512)           0           leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# auxiliary (Dense)                (None, 24)            12312       globalaveragepooling2d_1[0][0]
# ====================================================================================================
# Total params: 1,565,016
# Trainable params: 1,563,096
# Non-trainable params: 1,920
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 1, 64, 64)     0
# ____________________________________________________________________________________________________
# generator_upsampling (Model)     (None, 1, 64, 64)     298177      noise_input[0][0]
#                                                                    image_input[0][0]
# ____________________________________________________________________________________________________
# discriminator (Model)            (None, 24)            1565016     generator_upsampling[1][0]
# ====================================================================================================
# Total params: 1,863,193
# Trainable params: 1,860,249
# Non-trainable params: 2,944
# ____________________________________________________________________________________________________
# 3168/3200 [============================>.] - ETA: 2s - Loss_D: 1.3292 - Loss_D_real: 0.6140 - Loss_D_gen: 2.0445 - Loss_G: 9.1573
# Dest labels:
# [ 9 11  7  5 10  4  6  7  0  0  8  1  9  8  8  8  4  7  0  0  5  1  2  8  6
#   2  1  2  4  5  9  1]
# Source labels:
# [ 5  6  6  3  8  4  9 10  0  0  3  5  3  8  6  3  2  0 11  8  4  7  3 10  8
#   6 10  0  9  8  6  1]
#
# Epoch 1/10000, Time: 243.527010918
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.3018 - Loss_D_real: 0.4190 - Loss_D_gen: 2.1847 - Loss_G: 10.2815
# Dest labels:
# [ 8  0  4  1  0  3  3  3  1  9  0  5  8  2  3  8  8  4  4  0  2 11  4  7  0
#   6  2 11  4 11  7 11]
# Source labels:
# [ 5  0  3  7  0  0  4  4  0  6  0  4  0  1  0  8  2  3  5  9 10  7  4 11 10
#   4  7 10  4  9  7  3]
#
# Epoch 2/10000, Time: 104.71461606
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.2911 - Loss_D_real: 0.3533 - Loss_D_gen: 2.2289 - Loss_G: 10.9703
# Dest labels:
# [ 0  5  0 11  7  5  9 10  9  6  7 11  7  0  5  3  2  7  9  0  9 11  7  7  1
#   1  1  2  1 10 11  9]
# Source labels:
# [ 7  5  8  4  7  3  5  7  2  9  2 11  7  6  3  8  8  9 10  0 10 11  7  5  8
#   2 10  5  5 11  5  9]
#
# Epoch 3/10000, Time: 104.808852911
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.2565 - Loss_D_real: 0.3223 - Loss_D_gen: 2.1906 - Loss_G: 11.3558
# Dest labels:
# [ 5  7  8  4  4  9 11 11  3  1  1 11  9  2  1  4  6  8  5  2  5  6  3  0 10
#   0  4  4  5  7  5  0]
# Source labels:
# [ 9  6  0  3  4  7  0 11  5  3  7  4  1  7  8  4 10  2 11  9  3  2 11  4  7
#   0 10  8  3  1  7  0]
#
# Epoch 4/10000, Time: 104.961913109
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.1773 - Loss_D_real: 0.2901 - Loss_D_gen: 2.0645 - Loss_G: 11.2973
# Dest labels:
# [ 3 10  7  1  2  1  2  3 10  5  3 11  6  0  9  4  0  7  6  1 10  7  0  6  1
#   6  7  9 10  9  3  5]
# Source labels:
# [ 5  0  6 11  0  7  1 11  1  0  7  4 10  4  6  5  2  8  2  7  6  7 11  9  9
#   3  0 10  5  1  2 11]
#
# Epoch 5/10000, Time: 104.771692991
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.1253 - Loss_D_real: 0.2794 - Loss_D_gen: 1.9712 - Loss_G: 11.9983
# Dest labels:
# [ 6  0  4 11  8  7  4 11  5  5  5  3  3  4  0  7  9  3  2  5  5  4 10  7  0
#   8  5  5 10 10  5  0]
# Source labels:
# [ 1  0  0 11  5  7  3 10  5  0  8  1  2  2  0 11  2  5 11  4  1 10  3  4  8
#   0  4  9  6  5 11  8]
#
# Epoch 6/10000, Time: 104.611501932
# 3168/3200 [============================>.] - ETA: 1s - Loss_D: 1.1395 - Loss_D_real: 0.2542 - Loss_D_gen: 2.0248 - Loss_G: 11.8808
# Dest labels:
# [11 11  6  3  6  8  7  8 11  3  0 11  7  1  2  4  9 10  5  3  3  2  6  4 11
#   4  4  2  5  3  9  2]
# Source labels:
# [ 3  9 10  3  7  5  1  2  8 10  0 10 11  6  4  7  0  0  1  5  2  7  9 10  5
#  10  0  7  4  9  4  0]
#
# Epoch 7/10000, Time: 104.549203157
# 2176/3200 [===================>..........] - ETA: 33s - Loss_D: 1.0709 - Loss_D_real: 0.2572 - Loss_D_gen: 1.8845 - Loss_G: 12.0757
